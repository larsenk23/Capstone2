# %%
import pandas as pd
import numpy as np
import json
from pandas.io.json import json_normalize

# %%
df = pd.read_csv('train_v2.csv', nrows = 250000 )
# Out:
# /Users/kasey.larsen/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_copy = df.copy()

# %%
df = df_copy.copy()

# %%
df.head()
# Out:
#   channelGrouping                              customDimensions      date  \
# 0  Organic Search             [{'index': '4', 'value': 'EMEA'}]  20171016
# 1        Referral    [{'index': '4', 'value': 'North America'}]  20171016
# 2          Direct    [{'index': '4', 'value': 'North America'}]  20171016
# 3  Organic Search             [{'index': '4', 'value': 'EMEA'}]  20171016
# 4  Organic Search  [{'index': '4', 'value': 'Central America'}]  20171016
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Firefox", "browserVersion": "not ...  3162355547410993243
# 1  {"browser": "Chrome", "browserVersion": "not a...  8934116514970143966
# 2  {"browser": "Chrome", "browserVersion": "not a...  7992466427990357681
# 3  {"browser": "Chrome", "browserVersion": "not a...  9075655783635761930
# 4  {"browser": "Chrome", "browserVersion": "not a...  6960673291025684308
#
#                                           geoNetwork  \
# ...

# %%
df[['index', 'value']] = df.customDimensions.str.split(", ",expand=True)

# %%
df.head()
# Out:
#   channelGrouping                              customDimensions      date  \
# 0  Organic Search             [{'index': '4', 'value': 'EMEA'}]  20171016
# 1        Referral    [{'index': '4', 'value': 'North America'}]  20171016
# 2          Direct    [{'index': '4', 'value': 'North America'}]  20171016
# 3  Organic Search             [{'index': '4', 'value': 'EMEA'}]  20171016
# 4  Organic Search  [{'index': '4', 'value': 'Central America'}]  20171016
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Firefox", "browserVersion": "not ...  3162355547410993243
# 1  {"browser": "Chrome", "browserVersion": "not a...  8934116514970143966
# 2  {"browser": "Chrome", "browserVersion": "not a...  7992466427990357681
# 3  {"browser": "Chrome", "browserVersion": "not a...  9075655783635761930
# 4  {"browser": "Chrome", "browserVersion": "not a...  6960673291025684308
#
#                                           geoNetwork  \
# ...

# %%
df['index'].value_counts()
# Out:
# [{'index': '4'    199866
# []                 50134
# Name: index, dtype: int64

# %%
df = df.drop(['customDimensions', 'index'], axis=1)

# %%
df.head()
# Out:
#   channelGrouping      date  \
# 0  Organic Search  20171016
# 1        Referral  20171016
# 2          Direct  20171016
# 3  Organic Search  20171016
# 4  Organic Search  20171016
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Firefox", "browserVersion": "not ...  3162355547410993243
# 1  {"browser": "Chrome", "browserVersion": "not a...  8934116514970143966
# 2  {"browser": "Chrome", "browserVersion": "not a...  7992466427990357681
# 3  {"browser": "Chrome", "browserVersion": "not a...  9075655783635761930
# 4  {"browser": "Chrome", "browserVersion": "not a...  6960673291025684308
#
#                                           geoNetwork  \
# 0  {"continent": "Europe", "subContinent": "Weste...
# 1  {"continent": "Americas", "subContinent": "Nor...
# 2  {"continent": "Americas", "subContinent": "Nor...
# 3  {"continent": "Asia", "subContinent": "Western...
# 4  {"continent": "Americas", "subContinent": "Cen...
#
# ...

# %%
df['value']= df['value'].str[10:-3]

# %%
df.head()
# Out:
#   channelGrouping      date  \
# 0  Organic Search  20171016
# 1        Referral  20171016
# 2          Direct  20171016
# 3  Organic Search  20171016
# 4  Organic Search  20171016
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Firefox", "browserVersion": "not ...  3162355547410993243
# 1  {"browser": "Chrome", "browserVersion": "not a...  8934116514970143966
# 2  {"browser": "Chrome", "browserVersion": "not a...  7992466427990357681
# 3  {"browser": "Chrome", "browserVersion": "not a...  9075655783635761930
# 4  {"browser": "Chrome", "browserVersion": "not a...  6960673291025684308
#
#                                           geoNetwork  \
# 0  {"continent": "Europe", "subContinent": "Weste...
# 1  {"continent": "Americas", "subContinent": "Nor...
# 2  {"continent": "Americas", "subContinent": "Nor...
# 3  {"continent": "Asia", "subContinent": "Western...
# 4  {"continent": "Americas", "subContinent": "Cen...
#
# ...

# %%
df['value'].value_counts()
# Out:
# North America      111593
# EMEA                45422
# APAC                31282
# South America        7459
# Central America      4110
# Name: value, dtype: int64

# %%
df['device']
# Out:
# 0         {"browser": "Firefox", "browserVersion": "not ...
# 1         {"browser": "Chrome", "browserVersion": "not a...
# 2         {"browser": "Chrome", "browserVersion": "not a...
# 3         {"browser": "Chrome", "browserVersion": "not a...
# 4         {"browser": "Chrome", "browserVersion": "not a...
#                                 ...
# 249995    {"browser": "Chrome", "browserVersion": "not a...
# 249996    {"browser": "Chrome", "browserVersion": "not a...
# 249997    {"browser": "Chrome", "browserVersion": "not a...
# 249998    {"browser": "Safari", "browserVersion": "not a...
# 249999    {"browser": "Chrome", "browserVersion": "not a...
# Name: device, Length: 250000, dtype: object

# %%
df[['browser', 'browserVersion', 'browserSize', 'oeratingSystem', 'operatingSystemVersion','isMobile', 'mobileDeviceBranding', 'mobileDeviceModel', 
   'mobileInputSelector', 'mobileDeviceInfo', 'mobileDeviceMarketingName', 'flashVersion',
   'language', 'screenColors', 'screenResolution', 'deviceCategory']] = df.device.str.split(", ",expand=True)

# %%
df.head()
# Out:
#   channelGrouping      date  \
# 0  Organic Search  20171016
# 1        Referral  20171016
# 2          Direct  20171016
# 3  Organic Search  20171016
# 4  Organic Search  20171016
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Firefox", "browserVersion": "not ...  3162355547410993243
# 1  {"browser": "Chrome", "browserVersion": "not a...  8934116514970143966
# 2  {"browser": "Chrome", "browserVersion": "not a...  7992466427990357681
# 3  {"browser": "Chrome", "browserVersion": "not a...  9075655783635761930
# 4  {"browser": "Chrome", "browserVersion": "not a...  6960673291025684308
#
#                                           geoNetwork  \
# 0  {"continent": "Europe", "subContinent": "Weste...
# 1  {"continent": "Americas", "subContinent": "Nor...
# 2  {"continent": "Americas", "subContinent": "Nor...
# 3  {"continent": "Asia", "subContinent": "Western...
# 4  {"continent": "Americas", "subContinent": "Cen...
#
# ...

# %%
df['browser'].value_counts()
# Out:
# {"browser": "Chrome"                                                  170820
# {"browser": "Safari"                                                   46383
# {"browser": "Firefox"                                                   9294
# {"browser": "Android Webview"                                           5335
# {"browser": "Internet Explorer"                                         5095
# {"browser": "Edge"                                                      2854
# {"browser": "Samsung Internet"                                          2626
# {"browser": "Opera Mini"                                                2138
# {"browser": "Safari (in-app)"                                           2021
# {"browser": "Opera"                                                     1349
# {"browser": "UC Browser"                                                 759
# {"browser": "YaBrowser"                                                  450
# ...

# %%
df['browser'] = df['browser'].str[13:-1]

# %%
df['browser'].value_counts()
# Out:
# Chrome                                                  170820
# Safari                                                   46383
# Firefox                                                   9294
# Android Webview                                           5335
# Internet Explorer                                         5095
# Edge                                                      2854
# Samsung Internet                                          2626
# Opera Mini                                                2138
# Safari (in-app)                                           2021
# Opera                                                     1349
# UC Browser                                                 759
# YaBrowser                                                  450
# Amazon Silk                                                233
# Coc Coc                                                    175
# Android Browser                                            146
# ...

# %%
df['browserVersion'].value_counts()
# Out:
# "browserVersion": "not available in demo dataset"    250000
# Name: browserVersion, dtype: int64

# %%
df = df.drop(['browserVersion', 'device'], axis=1)

# %%
df['browserSize'].value_counts()
# Out:
# "browserSize": "not available in demo dataset"    250000
# Name: browserSize, dtype: int64

# %%
df = df.drop(['browserSize'], axis=1)

# %%
df['oeratingSystem'].value_counts()
# Out:
# "operatingSystem": "Windows"             89841
# "operatingSystem": "Macintosh"           64462
# "operatingSystem": "Android"             45274
# "operatingSystem": "iOS"                 31584
# "operatingSystem": "Linux"                9269
# "operatingSystem": "Chrome OS"            7289
# "operatingSystem": "(not set)"            1641
# "operatingSystem": "Windows Phone"         272
# "operatingSystem": "Samsung"               130
# "operatingSystem": "Tizen"                  97
# "operatingSystem": "BlackBerry"             47
# "operatingSystem": "OS/2"                   22
# "operatingSystem": "Xbox"                   21
# "operatingSystem": "Nintendo Wii"           19
# "operatingSystem": "Firefox OS"             15
# "operatingSystem": "Nintendo WiiU"           8
# "operatingSystem": "FreeBSD"                 3
# "operatingSystem": "Playstation Vita"        2
# "operatingSystem": "Nintendo 3DS"            2
# "operatingSystem": "Nokia"                   1
# ...

# %%
df['oeratingSystem'] = df['oeratingSystem'].str[20:-1]

# %%
df['oeratingSystem'].value_counts()
# Out:
# Windows             89841
# Macintosh           64462
# Android             45274
# iOS                 31584
# Linux                9269
# Chrome OS            7289
# (not set)            1641
# Windows Phone         272
# Samsung               130
# Tizen                  97
# BlackBerry             47
# OS/2                   22
# Xbox                   21
# Nintendo Wii           19
# Firefox OS             15
# Nintendo WiiU           8
# FreeBSD                 3
# Playstation Vita        2
# Nintendo 3DS            2
# Nokia                   1
# SymbianOS               1
# Name: oeratingSystem, dtype: int64

# %%
df['operatingSystemVersion'].value_counts()
# Out:
# "operatingSystemVersion": "not available in demo dataset"    250000
# Name: operatingSystemVersion, dtype: int64

# %%
df = df.drop(['operatingSystemVersion'], axis=1)

# %%
df['isMobile'].value_counts()
# Out:
# "isMobile": false    170597
# "isMobile": true      79403
# Name: isMobile, dtype: int64

# %%
df['isMobile'] = df['isMobile'].str[12:]

# %%
df['isMobile'].value_counts()
# Out:
# false    170597
# true      79403
# Name: isMobile, dtype: int64

# %%
df['mobileDeviceBranding'].value_counts()
# Out:
# "mobileDeviceBranding": "not available in demo dataset"    250000
# Name: mobileDeviceBranding, dtype: int64

# %%
df = df.drop(['mobileDeviceBranding'], axis=1)

# %%
df['mobileDeviceModel'].value_counts()
# Out:
# "mobileDeviceModel": "not available in demo dataset"    250000
# Name: mobileDeviceModel, dtype: int64

# %%
df = df.drop(['mobileDeviceModel'], axis=1)

# %%
df['mobileInputSelector'].value_counts()
# Out:
# "mobileInputSelector": "not available in demo dataset"    250000
# Name: mobileInputSelector, dtype: int64

# %%
df['mobileDeviceInfo'].value_counts()
# Out:
# "mobileDeviceInfo": "not available in demo dataset"    250000
# Name: mobileDeviceInfo, dtype: int64

# %%
df['mobileDeviceMarketingName'].value_counts()
# Out:
# "mobileDeviceMarketingName": "not available in demo dataset"    250000
# Name: mobileDeviceMarketingName, dtype: int64

# %%
df['flashVersion'].value_counts()
# Out:
# "flashVersion": "not available in demo dataset"    250000
# Name: flashVersion, dtype: int64

# %%
df['language'].value_counts()
# Out:
# "language": "not available in demo dataset"    250000
# Name: language, dtype: int64

# %%
df['screenColors'].value_counts()
# Out:
# "screenColors": "not available in demo dataset"    250000
# Name: screenColors, dtype: int64

# %%
df['screenResolution'].value_counts()
# Out:
# "screenResolution": "not available in demo dataset"    250000
# Name: screenResolution, dtype: int64

# %%
df = df.drop(['mobileInputSelector', 'mobileDeviceInfo', 'mobileDeviceMarketingName', 'flashVersion', 'language', 
             'screenColors', 'screenResolution'], axis=1)

# %%
df['deviceCategory'].value_counts()
# Out:
# "deviceCategory": "desktop"}    170585
# "deviceCategory": "mobile"}      69942
# "deviceCategory": "tablet"}       9473
# Name: deviceCategory, dtype: int64

# %%
df['deviceCategory'] = df['deviceCategory'].str[19:-2]

# %%
df['deviceCategory'].value_counts()
# Out:
# desktop    170585
# mobile      69942
# tablet       9473
# Name: deviceCategory, dtype: int64

# %%
df.head()
# Out:
#   channelGrouping      date        fullVisitorId  \
# 0  Organic Search  20171016  3162355547410993243
# 1        Referral  20171016  8934116514970143966
# 2          Direct  20171016  7992466427990357681
# 3  Organic Search  20171016  9075655783635761930
# 4  Organic Search  20171016  6960673291025684308
#
#                                           geoNetwork  \
# 0  {"continent": "Europe", "subContinent": "Weste...
# 1  {"continent": "Americas", "subContinent": "Nor...
# 2  {"continent": "Americas", "subContinent": "Nor...
# 3  {"continent": "Asia", "subContinent": "Western...
# 4  {"continent": "Americas", "subContinent": "Cen...
#
#                                                 hits  socialEngagementType  \
# 0  [{'hitNumber': '1', 'time': '0', 'hour': '17',...  Not Socially Engaged
# 1  [{'hitNumber': '1', 'time': '0', 'hour': '10',...  Not Socially Engaged
# 2  [{'hitNumber': '1', 'time': '0', 'hour': '17',...  Not Socially Engaged
# ...

# %%
df[['continent', 'subContinent', 'country', 'region', 'metro', 'city', 'cityId', 'networkDomain', 'latitude', 'longitude',
   'networkLocation']] = df.geoNetwork.str.split(", ",expand=True)

# %%
df['continent'].value_counts()
# Out:
# {"continent": "Americas"     129473
# {"continent": "Asia"          57404
# {"continent": "Europe"        53316
# {"continent": "Africa"         5450
# {"continent": "Oceania"        4002
# {"continent": "(not set)"       355
# Name: continent, dtype: int64

# %%
df['continent'] = df['continent'].str[15:-1]

# %%
df['continent'].value_counts()
# Out:
# Americas     129473
# Asia          57404
# Europe        53316
# Africa         5450
# Oceania        4002
# (not set)       355
# Name: continent, dtype: int64

# %%
df['continent'] = df['continent'].replace('(not set)', np.nan)

# %%
df['continent'].isna().sum()
# Out:
# 355

# %%
df['subContinent'].value_counts()
# Out:
# "subContinent": "Northern America"      111597
# "subContinent": "Southeast Asia"         18590
# "subContinent": "Southern Asia"          17152
# "subContinent": "Western Europe"         16697
# "subContinent": "Northern Europe"        15614
# "subContinent": "Eastern Asia"           12368
# "subContinent": "South America"          12303
# "subContinent": "Eastern Europe"         11280
# "subContinent": "Southern Europe"         9725
# "subContinent": "Western Asia"            8994
# "subContinent": "Central America"         4818
# "subContinent": "Australasia"             3955
# "subContinent": "Northern Africa"         2781
# "subContinent": "Western Africa"          1060
# "subContinent": "Southern Africa"          865
# "subContinent": "Caribbean"                755
# "subContinent": "Eastern Africa"           612
# "subContinent": "(not set)"                355
# "subContinent": "Central Asia"             300
# "subContinent": "Middle Africa"            132
# ...

# %%
df['subContinent'] = df['subContinent'].replace('(not set)', np.nan)

# %%
df['subContinent'] = df['subContinent'].str[17:-1]

# %%
df['subContinent'].value_counts()
# Out:
# Northern America      111597
# Southeast Asia         18590
# Southern Asia          17152
# Western Europe         16697
# Northern Europe        15614
# Eastern Asia           12368
# South America          12303
# Eastern Europe         11280
# Southern Europe         9725
# Western Asia            8994
# Central America         4818
# Australasia             3955
# Northern Africa         2781
# Western Africa          1060
# Southern Africa          865
# Caribbean                755
# Eastern Africa           612
# (not set)                355
# Central Asia             300
# Middle Africa            132
# Melanesia                 21
# Micronesian Region        21
# Polynesia                  5
# Name: subContinent, dtype: int64

# %%
df['country'].value_counts()
# Out:
# "country": "United States"            104134
# "country": "India"                     14941
# "country": "United Kingdom"            10376
# "country": "Canada"                     7452
# "country": "Brazil"                     5992
#                                        ...
# "country": "San Marino"                    1
# "country": "Caribbean Netherlands"         1
# "country": "Guinea-Bissau"                 1
# "country": "Grenada"                       1
# "country": "Equatorial Guinea"             1
# Name: country, Length: 204, dtype: int64

# %%
df['country'] = df['country'].str[12:-1]

# %%
pd.set_option('display.max_rows', 500)

# %%
df['country'].value_counts()
# Out:
# United States               104134
# India                        14941
# United Kingdom               10376
# Canada                        7452
# Brazil                        5992
# Vietnam                       5421
# Germany                       5406
# Japan                         5002
# Thailand                      4656
# France                        4616
# Turkey                        4463
# Mexico                        4111
# Taiwan                        3456
# Australia                     3383
# Spain                         3381
# Netherlands                   3381
# Italy                         3078
# Russia                        2890
# Indonesia                     2535
# Poland                        2319
# Philippines                   2081
# Singapore                     1966
# Malaysia                      1673
# Romania                       1635
# South Korea                   1604
# Peru                          1571
# Ireland                       1555
# ...

# %%
df['region'].value_counts()
# Out:
# "region": "not available in demo dataset"        136155
# "region": "California"                            29885
# "region": "(not set)"                              7383
# "region": "New York"                               7237
# "region": "England"                                3689
# "region": "Texas"                                  3077
# "region": "Illinois"                               2392
# "region": "Washington"                             2155
# "region": "Bangkok"                                1863
# "region": "Maharashtra"                            1850
# "region": "Ontario"                                1784
# "region": "Delhi"                                  1578
# "region": "Karnataka"                              1569
# "region": "Taipei City"                            1555
# "region": "Istanbul"                               1463
# "region": "Tamil Nadu"                             1337
# "region": "State of Sao Paulo"                     1299
# ...

# %%
df['metro'].value_counts()
# Out:
# "metro": "not available in demo dataset"                              136155
# "metro": "(not set)"                                                   57592
# "metro": "San Francisco-Oakland-San Jose CA"                           26560
# "metro": "New York NY"                                                  7384
# "metro": "London"                                                       3402
# "metro": "Los Angeles CA"                                               2742
# "metro": "Chicago IL"                                                   2392
# "metro": "Seattle-Tacoma WA"                                            2155
# "metro": "Austin TX"                                                    1044
# "metro": "Washington DC (Hagerstown MD)"                                1032
# "metro": "Dallas-Ft. Worth TX"                                          1000
# "metro": "Atlanta GA"                                                    835
# ...

# %%
df['city'].value_counts()
# Out:
# "city": "not available in demo dataset"        136155
# "city": "Mountain View"                         11089
# "city": "(not set)"                              9644
# "city": "New York"                               7209
# "city": "San Francisco"                          5314
# "city": "Sunnyvale"                              3884
# "city": "London"                                 3418
# "city": "San Jose"                               2918
# "city": "Chicago"                                2346
# "city": "Los Angeles"                            2302
# "city": "Bangkok"                                1863
# "city": "Ho Chi Minh City"                       1578
# "city": "Bengaluru"                              1569
# "city": "Toronto"                                1500
# "city": "Istanbul"                               1463
# "city": "Seattle"                                1397
# "city": "Sao Paulo"                              1264
# ...

# %%
df['cityId'].value_counts()
# Out:
# "cityId": "not available in demo dataset"    250000
# Name: cityId, dtype: int64

# %%
df['networkDomain'].value_counts()
# Out:
# "networkDomain": "(not set)"          72283
# "networkDomain": "unknown.unknown"    39711
# "networkDomain": "comcast.net"         7934
# "networkDomain": "rr.com"              4049
# "networkDomain": "verizon.net"         3916
#                                       ...
# "networkDomain": "admiral.at"             1
# "networkDomain": "66.pl"                  1
# "networkDomain": "0und1.net"              1
# "networkDomain": "iscac.pt"               1
# "networkDomain": "alfservis.cz"           1
# Name: networkDomain, Length: 13644, dtype: int64

# %%
df['latitude'].value_counts()
# Out:
# "latitude": "not available in demo dataset"    250000
# Name: latitude, dtype: int64

# %%
df['longitude'].value_counts()
# Out:
# "longitude": "not available in demo dataset"    250000
# Name: longitude, dtype: int64

# %%
df['networkLocation'].value_counts()
# Out:
# "networkLocation": "not available in demo dataset"}    250000
# Name: networkLocation, dtype: int64

# %%
df = df.drop(['geoNetwork', 'cityId', 'latitude', 'longitude', 'networkLocation', 'region', 'metro', 'city', 'networkDomain'], axis=1)

# %%
df.head()
# Out:
#   channelGrouping      date        fullVisitorId  \
# 0  Organic Search  20171016  3162355547410993243
# 1        Referral  20171016  8934116514970143966
# 2          Direct  20171016  7992466427990357681
# 3  Organic Search  20171016  9075655783635761930
# 4  Organic Search  20171016  6960673291025684308
#
#                                                 hits  socialEngagementType  \
# 0  [{'hitNumber': '1', 'time': '0', 'hour': '17',...  Not Socially Engaged
# 1  [{'hitNumber': '1', 'time': '0', 'hour': '10',...  Not Socially Engaged
# 2  [{'hitNumber': '1', 'time': '0', 'hour': '17',...  Not Socially Engaged
# 3  [{'hitNumber': '1', 'time': '0', 'hour': '9', ...  Not Socially Engaged
# 4  [{'hitNumber': '1', 'time': '0', 'hour': '14',...  Not Socially Engaged
#
#                                               totals  \
# 0  {"visits": "1", "hits": "1", "pageviews": "1",...
# 1  {"visits": "1", "hits": "2", "pageviews": "2",...
# ...

# %%
df['socialEngagementType'].value_counts()
# Out:
# Not Socially Engaged    250000
# Name: socialEngagementType, dtype: int64

# %%
df = df.drop(['socialEngagementType'], axis=1)

# %%
df.head()
# Out:
#   channelGrouping      date        fullVisitorId  \
# 0  Organic Search  20171016  3162355547410993243
# 1        Referral  20171016  8934116514970143966
# 2          Direct  20171016  7992466427990357681
# 3  Organic Search  20171016  9075655783635761930
# 4  Organic Search  20171016  6960673291025684308
#
#                                                 hits  \
# 0  [{'hitNumber': '1', 'time': '0', 'hour': '17',...
# 1  [{'hitNumber': '1', 'time': '0', 'hour': '10',...
# 2  [{'hitNumber': '1', 'time': '0', 'hour': '17',...
# 3  [{'hitNumber': '1', 'time': '0', 'hour': '9', ...
# 4  [{'hitNumber': '1', 'time': '0', 'hour': '14',...
#
#                                               totals  \
# 0  {"visits": "1", "hits": "1", "pageviews": "1",...
# 1  {"visits": "1", "hits": "2", "pageviews": "2",...
# 2  {"visits": "1", "hits": "2", "pageviews": "2",...
# 3  {"visits": "1", "hits": "2", "pageviews": "2",...
# 4  {"visits": "1", "hits": "2", "pageviews": "2",...
#
# ...

# %%
df['hits'][0]
# Out:
# "[{'hitNumber': '1', 'time': '0', 'hour': '17', 'minute': '0', 'isInteraction': True, 'isEntrance': True, 'isExit': True, 'referer': 'https://www.google.co.uk/search?q=water+bottle&ie=utf-8&num=100&oe=utf-8&hl=en&gl=GB&uule=w+CAIQIFISCamRx0IRO1oCEXoliDJDoPjE&glp=1&gws_rd=cr&fg=1', 'page': {'pagePath': '/google+redesign/bags/water+bottles+and+tumblers', 'hostname': 'shop.googlemerchandisestore.com', 'pageTitle': 'Water Bottles & Tumblers | Drinkware | Google Merchandise Store', 'pagePathLevel1': '/google+redesign/', 'pagePathLevel2': '/bags/', 'pagePathLevel3': '/water+bottles+and+tumblers', 'pagePathLevel4': ''}, 'transaction': {'currencyCode': 'USD'}, 'item': {'currencyCode': 'USD'}, 'appInfo': {'screenName': 'shop.googlemerchandisestore.com/google+redesign/bags/water+bottles+and+tumblers', 'landingScreenName': 'shop.googlemerchandisestore.com/google+redesign/bags/water+bottles+and+tumblers', 'exitScreenName': 'shop.googlemerchandisestore.com/google+redesign/bags/water+bottles+and+t
# ...

# %%
df['totals'][0]
# Out:
# '{"visits": "1", "hits": "1", "pageviews": "1", "bounces": "1", "newVisits": "1", "sessionQualityDim": "1"}'

# %%
df[['visits', 'hits', 'pageviews', 'timeOnSite', 'newVisits', 
    'sessionQualityDim', 'c_1', 'c_2', 'c_3']] = df.totals.str.split(", ",expand=True)

# %%
df['visits'].value_counts()
# Out:
# {"visits": "1"    250000
# Name: visits, dtype: int64

# %%
df = df.drop(['visits'], axis=1)

# %%
df['hits'].value_counts()
# Out:
# "hits": "1"      127196
# "hits": "2"       35501
# "hits": "3"       19257
# "hits": "4"       11760
# "hits": "5"        9150
# "hits": "6"        6791
# "hits": "7"        5405
# "hits": "8"        4288
# "hits": "9"        3526
# "hits": "10"       2908
# "hits": "11"       2532
# "hits": "12"       2165
# "hits": "13"       1879
# "hits": "14"       1647
# "hits": "15"       1424
# "hits": "16"       1271
# "hits": "17"       1118
# "hits": "18"       1000
# "hits": "19"        848
# "hits": "20"        834
# "hits": "21"        721
# "hits": "22"        626
# "hits": "23"        568
# "hits": "25"        515
# "hits": "24"        510
# "hits": "26"        462
# "hits": "27"        405
# "hits": "28"        367
# "hits": "30"        320
# "hits": "29"        318
# "hits": "31"        292
# "hits": "32"        277
# "hits": "33"        241
# "hits": "35"        219
# "hits": "34"        217
# "hits": "36"        210
# "hits": "37"        191
# "hits": "38"        167
# ...

# %%
df['hits'] = df['hits'].str[9:-1]

# %%
df['pageviews'].value_counts()
# Out:
# "pageviews": "1"              128867
# "pageviews": "2"               37329
# "pageviews": "3"               20465
# "pageviews": "4"               12583
# "pageviews": "5"                9335
# "pageviews": "6"                6872
# "pageviews": "7"                5311
# "pageviews": "8"                4298
# "pageviews": "9"                3473
# "pageviews": "10"               2793
# "pageviews": "11"               2367
# "pageviews": "12"               1864
# "pageviews": "13"               1623
# "pageviews": "14"               1478
# "pageviews": "15"               1203
# "pageviews": "16"               1049
# "pageviews": "17"                939
# "pageviews": "18"                793
# "pageviews": "19"                692
# "pageviews": "20"                628
# "pageviews": "21"                565
# "pageviews": "22"                470
# "pageviews": "23"                466
# "pageviews": "24"                414
# "pageviews": "25"                306
# ...

# %%
df['timeOnSite'].value_counts()
# Out:
# "bounces": "1"           115548
# "bounces": "1"}           12724
# "timeOnSite": "4"          1434
# "timeOnSite": "5"          1385
# "timeOnSite": "6"          1248
#                           ...
# "timeOnSite": "3527"}         1
# "timeOnSite": "3471"          1
# "timeOnSite": "1493"          1
# "timeOnSite": "3127"}         1
# "timeOnSite": "3054"          1
# Name: timeOnSite, Length: 4847, dtype: int64

# %%
df = df.drop(['timeOnSite'], axis=1)

# %%
df['newVisits'].value_counts()
# Out:
# "newVisits": "1"}             104205
# "newVisits": "1"               86906
# "sessionQualityDim": "1"}      18027
# "sessionQualityDim": "2"}       3408
# "transactions": "1"             2600
# "sessionQualityDim": "3"}       1082
# "sessionQualityDim": "4"}        589
# "sessionQualityDim": "5"}        417
# "sessionQualityDim": "6"}        257
# "sessionQualityDim": "7"}        187
# "sessionQualityDim": "8"}        147
# "sessionQualityDim": "9"}        126
# "sessionQualityDim": "10"}        97
# "sessionQualityDim": "12"}        80
# "sessionQualityDim": "13"}        79
# "transactions": "2"               74
# "sessionQualityDim": "11"}        70
# "sessionQualityDim": "16"}        60
# "sessionQualityDim": "15"}        53
# "sessionQualityDim": "14"}        50
# "sessionQualityDim": "19"}        49
# "sessionQualityDim": "17"}        44
# "sessionQualityDim": "18"}        43
# "sessionQualityDim": "57"}        38
# "sessionQualityDim": "32"}        37
# ...

# %%
df['sessionQualityDim'].value_counts()
# Out:
# "sessionQualityDim": "1"}            77167
# "sessionQualityDim": "2"}             3110
# "sessionQualityDim": "3"}             1143
# "sessionQualityDim": "4"}              622
# "sessionQualityDim": "5"}              474
#                                      ...
# "transactionRevenue": "90710000"         1
# "transactionRevenue": "210160000"        1
# "transactionRevenue": "59850000"         1
# "transactionRevenue": "351800000"        1
# "transactionRevenue": "824680000"        1
# Name: sessionQualityDim, Length: 1746, dtype: int64

# %%
df['trafficSource'][0]
# Out:
# '{"campaign": "(not set)", "source": "google", "medium": "organic", "keyword": "water bottle", "adwordsClickInfo": {"criteriaParameters": "not available in demo dataset"}}'
